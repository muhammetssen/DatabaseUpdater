# %%
import pandas
sheet = pandas.read_excel('excel.xlsx',sheet_name='Influencers')

# %%
sheet.head()
# Out:
#            General              Unnamed: 1                     Unnamed: 2  \
# 0  Influencer Name  Channel / Account Name                          Email
# 1   Shelley Brewer                 Blogger    info@steampoweredfamily.com
# 2      Karyn Tripp                 Blogger        karyn@teachbesideme.com
# 3       Anne Carey                 Blogger  leftbraincraftbrain@gmail.com
# 4      AWESMR Kids                Youtuber       awesmrbusiness@gmail.com
#
#       Unnamed: 3 Unnamed: 4              Unnamed: 5 Unnamed: 6  \
# 0  Contact Phone    Website  Notes about Influencer    Country
# 1            NaN        NaN                     NaN        NaN
# 2            NaN        NaN                     NaN        NaN
# 3            NaN        NaN                     NaN        NaN
# 4            NaN        NaN                     NaN         US
#
#                               TangiPlay  \
# 0  TangiPlay Relevance Point (out of 5)
# 1                                   NaN
# ...
